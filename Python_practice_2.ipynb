# %% [markdown]
# *****

# %% [markdown]
# ### Question 1 **[50 pts]**:

# %% [markdown]
# **a)** **[15 pts]** Define a function called `isSymmetrical` that takes a string value as a parameter and returns `TRUE` if the given string is Symmetrical. A string is said to be symmetrical if the reverse of the string is the same as string. For example, “madam” is symmetrical, but “water” is not symmetrical.

# %%
#INSERT YOUR ANSWER HERE.

def isSymmetrical(myString): 
    
    if str is None or not str:
        return False

    mid = (len(myString)-1)//2
    start = 0
    last = len(myString)-1
    flag = 0

    while(start<mid): 

        if (myString[start]== myString[last]): 
            
            start += 1
            last -= 1
            
        else: 
            flag = 1
            break; 
            
    if flag == 0: 
        return True
    else: 
        return False

#Testing a string to check whether it is symmetric or not 
testString = "madam"

print(isSymmetrical(testString))
 
#Output: 'True'
# Out:
# True

# %% [markdown]
# **b)** **[5 pts]** Modify the `isSymmetrical` function you created in Q1.a to take any type of data as an input and return `TRUE` if the input is symmetrical. For example, "12321" is symmetrical, but "12345" is not symmetrical.

# %%
#INSERT YOUR ANSWER HERE.

def isSymmetrical(myString): 

    mid = (len(myString)-1)//2
    start = 0
    last = len(myString)-1
    flag = 0

    while(start<mid): 

        if (myString[start]== myString[last]): 
            
            start += 1
            last -= 1
            
        else: 
            flag = 1
            break; 
            
    if flag == 0: 
        return True
    else: 
        return False

#Testing any type of data to check whether it is symmetric or not 
myData = (1, 2, 3, 2)

print(isSymmetrical(myData))

#Output: 'False'
# Out:
# False

# %% [markdown]
# **c)** **[10 pts]** Define a function called `isSymmetricalVec` that calls `isSymmetrical` function you updated in Q1.b to take a list of elements and return their results in a list.  For example, given \["1441", "Apple", "radar", "232", "plane"\] the function returns \[`TRUE`, `FALSE`, `TRUE`, `TRUE`, `FALSE`\]

# %%
#INSERT YOUR ANSWER HERE. 

def isSymmetricalVec(myString): 

    mid = (len(myString)-1)//2
    start = 0
    last = len(myString)-1
    flag = 0

    while(start<mid): 

        if (myString[start]== myString[last]): 
            
            start += 1
            last -= 1
            
        else: 
            flag = 1
            break; 
            
    if flag == 0: 
        return True
    else: 
        return False

#Testing a list of elements to check whether it is symmetric or not 
test = ["1221", "madam", "hello world"]
    
final = [isSymmetricalVec(i) for i in test]
print(final) 

#Output: '[True, True, False]'
# Out:
# [True, True, False]

# %% [markdown]
# **d)** **[10 pts]** Define a function called `isSymmetricalDict` by modifying the function you created in Q1.c to return the results in a dictionary with their corresponding input elements. \
# For example, given \["1441", "Apple", "radar", "232", "plane"\] the function returns {"1441": `TRUE`, "Apple": `FALSE`, "radar": `TRUE`, "232": `TRUE`, "plane": `FALSE`\}

# %%
#INSERT YOUR ANSWER HERE.

def isSymmetricalDict(myString): 

    mid = (len(myString)-1)//2
    start = 0
    last = len(myString)-1
    flag = 0

    while(start<mid): 

        if (myString[start]== myString[last]): 
            
            start += 1
            last -= 1
            
        else: 
            flag = 1
            break; 
            
    if flag == 0: 
        return True
    else: 
        return False

#Testing a list of elements to check whether it is symmetric or not 
myData = ["1221", "madam", "hello world"]
    
final = [isSymmetricalDict(i) for i in myData]

myDic = {myData[i]: final[i] for i in range(len(myData))} 
print(myDic)

#Output: '{'1221': True, 'madam': True, 'hello world': False}'
# Out:
# {'1221': True, 'madam': True, 'hello world': False}

# %% [markdown]
# **e)** **[10 pts]** Define a function called `isSymmetricalTuple` by modifying the function you created in Q1.d to traverse the values of the returned dictionary **in reverse order** and return the dictionary keys that has a **`TRUE`** value as a tuple.  For example, given \["1441", "Apple", "radar", "232", "plane"\] the function returns ("232", "radar","1441").

# %%
#INSERT YOUR ANSWER HERE.

def isSymmetricalTuple(myString): 

    mid = (len(myString)-1)//2
    start = 0
    last = len(myString)-1
    flag = 0

    while(start<mid): 

        if (myString[start]== myString[last]): 
            
            start += 1
            last -= 1
            
        else: 
            flag = 1
            break; 
            
    if flag == 0: 
        return True
    else: 
        return False

#Testing a list of elements to check whether it is symmetric or not 
myData = ["1221", "madam", "hello world"]
    
final = [isSymmetricalTuple(i) for i in myData]

original_dict = {myData[i]: final[i] for i in range(len(myData))} 
print(original_dict)

new_dict={}
for k,v in original_dict.items():
    dict_element={k:v}
    dict_element.update(new_dict)
    new_dict=dict_element

print(new_dict)

myTrueDict = {k:v for (k,v) in new_dict.items() if v == True}
myTuple = tuple(myTrueDict.keys())
print(myTuple)

'''Output: 
{'1221': True, 'madam': True, 'hello world': False}
{'hello world': False, 'madam': True, '1221': True}
('madam', '1221')'''
# Out:
# {'1221': True, 'madam': True, 'hello world': False}
# {'hello world': False, 'madam': True, '1221': True}
# ('madam', '1221')
# "Output: \n{'1221': True, 'madam': True, 'hello world': False}\n{'hello world': False, 'madam': True, '1221': True}\n('madam', '1221')"

# %% [markdown]
# *****

# %% [markdown]
# ### Question 2 **[80 pts]** :

# %% [markdown]
# **a)** **[15 pts]** Define a function called `minSubStr` that takes two string arguments ( S and T ), and returns `TRUE` if the characters of *T* exist in *S*, else returns `FALSE`. For example: given `S = 'xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx'` and `T = "ABC"`, returns `TRUE` (`T = "ABCD"`, returns `FALSE)`

# %%
#INSERT YOUR ANSWER HERE.

S = input("Enter the first string: ")
T = input("Enter the second string to check if the characters exist in the first string: ")

def minSubStr(S, T):
    
    if all(i in S for i in T):
        return True
    else:     
        return False

minSubStr(S, T)

'''Output: 
Enter the first string:  "xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx"
Enter the second string to check if the characters exist in the first string:  "ABCD"
False'''
# Out:
# Enter the first string:  xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx
# Enter the second string to check if the characters exist in the first string:  ABCD
# 'Output: \nEnter the first string:  xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx\nEnter the second string to check if the characters exist in the first string:  ABCD\nFalse'

# %% [markdown]
# **b)** **[15 pts]** Modify your `minSubStr` function defined in Q2.a to return the first possible substring (traversing from left) containing all the elements of `T`. For example: given `S = 'xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx'` and `T = "ABC"`, returns **`"BxxAxxC"`**

# %%
#INSERT YOUR ANSWER HERE.

S = input("Enter the first string: ")
T = input("Enter the substring: ")



def minSubStr2b(S, T):
    todo = set(T)
    start = -1
    for i, ch in enumerate(S):
        if not todo:
            return S[start:i]
        if ch in todo:
            todo.discard(ch)
            if start < 0:
                start = i
minSubStr2b(S, T)

'''S = "xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx"
T = "ABC"
Output: 'BxxAxxC' '''
# Out:
# Enter the first string:  xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx
# Enter the substring:  ABC
# 'S = "xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx"\nT = "ABC"\nOutput: \'BxxAxxC\' '

# %% [markdown]
# **c)** **[20 pts]** Modify your `minSubStr` function defined in Q2.b to return the shortest substring containing all the elements of T. For example: given `S = 'xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx'` and `T = "ABC"`, returns **`"AxCxB"`**

# %%
#INSERT YOUR ANSWER HERE.

no_of_chars = 256

S = input("Enter the first string: ")
T = input("Enter the substring: ")

def minSubStr2c(S, T):
 
    len1 = len(S)
    len2 = len(T)
 
    hash_T = [0] * no_of_chars
    hash_S= [0] * no_of_chars
 
    for i in range(0, len2):
        hash_T[ord(T[i])] += 1
 
    start, start_index, min_len = 0, -1, float('inf')
 
    count = 0  
    for j in range(0, len1):
 
        hash_S[ord(S[j])] += 1
 
        if (hash_S[ord(S[j])] <=
                hash_T[ord(S[j])]):
            count += 1
 
        if count == len2:
 
            while (hash_S[ord(S[start])] >
                   hash_T[ord(S[start])] or
                   hash_T[ord(S[start])] == 0):
 
                if (hash_S[ord(S[start])] >
                        hash_T[ord(S[start])]):
                    hash_S[ord(S[start])] -= 1
                start += 1
 
            len_window = j - start + 1
            if min_len > len_window:
 
                min_len = len_window
                start_index = start
 
    return S[start_index: start_index + min_len]
 
 
if __name__ == "__main__":
 
    print(minSubStr2c(S, T))
    
'''Output: 
S = "xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx"
T = "ABC"
Output: 'AxCxB' '''
# Out:
# Enter the first string:  xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx
# Enter the substring:  ABC
# AxCxB

# %% [markdown]
# **d)** **[30 pts]** modify your `minSubStr` function defined in Q2.c to return the shortest substring containing all the elements of T in order. For example: given `S = 'xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx'` and `T = "ABC"`, returns **`"AxxBxC"`**

# %%
#INSERT YOUR ANSWER HERE.

S = input("Enter the first string: ")
T = input("Enter the substring: ")

'''The following function maps characters of T to their first positions in string S 
and gets the range between the minimum and maximum positions'''
    
mapPos    = [S.find(k) for k in T]
minSubStr2d = S[min(mapPos):max(mapPos)+1]

print(minSubStr2d)

''' Output:
S   = "xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx"
T   = "BC"
Output: 'BxxAxxC' '''
# Out:
# Enter the first string:  xBxxAxxCxxAxCxxBxxxAxCxBxxxAxxBxCx
# Enter the substring:  BC
# BxxAxxC

# %% [markdown]
# *****

# %% [markdown]
# ### Question 3 **[30 pts]**:

# %% [markdown]
# **a)** Complete the given code to define three classes, Shape, Oval and Circle.
# - Shape will be the parent class of Oval and Circle.
# - Randomly create ten objects from Oval and Circle classes using the ``for`` loop given below
# - Your code should produce correct number of Shapes, Circle and Oval objects. The count of objects should be calculated within the class definitions.
#   - Example output (note that since it is random every time it will be a different number of shapes) \\
#   There are  10 random shape objects ['Circle', 'Circle', 'Circle', 'Circle', 'Oval', 'Circle', 'Oval', 'Oval', 'Circle', 'Circle'] \\
# 	 3 of them are ovals \\
# 	 7 of them are cirlces \\

# %%
#INSERT YOUR ANSWER HERE.

# Define Shape class
class Shape:
    #constructor of Shape class
    def __init__(self):
        #initializing name to Shape
        self.name="Shape"
        
# Define Oval class
class Oval(Shape):#Oval is inheriting Shape class
    #constructor of Oval class
    def __init__(self):
        #initializing name to Oval
        self.name="Oval"
        
# Define Circle class
class Circle(Shape):#Circle class inheriting Shape class
    #constructor of Circle class
    def __init__(self):
        #initializing name to Circle
        self.name="Circle"
# Run the following lines of code


from random import choice
list_of_shapes = [choice(['Circle', 'Oval']) for x in range(10)]

count_oval=0#initializing count_oval to 0 (will store the count of Oval objects)
count_circle=0#initializing count_circle to 0 (will store the count of Circle objects)

for shape in list_of_shapes:
 if shape == 'Oval':#if the object is of Oval
   #insert an object of oval
   #than increment the count of Oval objects by 1
   count_oval=count_oval+1
 else:#else the object if of type Circle
   #insert an object of circle class
   #than increment the count of circle by 1
   count_circle=count_circle+1
   
# Print the list_of_shapes
print(list_of_shapes)
# Print number of shape objects
print("There are",len(list_of_shapes),"random shape objects")
# Print number of Oval objects
print(count_oval,"of them are ovals")
# Print number of circle objects
print(count_circle,"of them are circles")

'''['Oval', 'Oval', 'Circle', 'Circle', 'Circle', 'Circle', 'Oval', 'Circle', 'Circle', 'Oval']
There are 10 random shape objects
4 of them are ovals
6 of them are circles'''
# Out:
# ['Oval', 'Oval', 'Circle', 'Circle', 'Circle', 'Circle', 'Oval', 'Circle', 'Circle', 'Oval']
# There are 10 random shape objects
# 4 of them are ovals
# 6 of them are circles
# "['Circle', 'Circle', 'Circle', 'Circle', 'Circle', 'Circle', 'Oval', 'Oval', 'Oval', 'Oval']\nThere are 10 random shape objects\n4 of them are ovals\n6 of them are circles"
